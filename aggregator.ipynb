# %%
import pandas as pd
import numpy as np
import math
from scipy.spatial.distance import pdist, squareform

# %%
df = pd.read_csv("../health_ai_mdav_demo.csv", index_col="ID")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 1 to 40
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         40 non-null     int64
#  1   Sex         40 non-null     object
#  2   ZIP         40 non-null     int64
#  3   SystolicBP  40 non-null     int64
#  4   BMI         40 non-null     float64
#  5   Diagnosis   40 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#              Age           ZIP  SystolicBP        BMI
# count  40.000000     40.000000   40.000000  40.000000
# mean   51.750000  53116.600000  114.600000  24.852500
# std    15.669258      1.150251   13.285427   2.720953
# min    25.000000  53115.000000   90.000000  20.100000
# 25%    41.500000  53116.000000  103.750000  22.775000
# 50%    52.500000  53117.000000  119.500000  24.750000
# 75%    66.000000  53117.250000  124.000000  26.650000
# max    77.000000  53119.000000  143.000000  31.500000

# %%
# df["Sex"] = df["Sex"].apply(lambda x: 0 if x == "F" else 1)

# %%
df.head()
# Out:
#     Age Sex    ZIP  SystolicBP   BMI     Diagnosis
# ID
# 1    27   F  53116         108  27.1  Hypertension
# 2    66   M  53118         123  25.2      Migraine
# 3    59   M  53118         126  22.8        Asthma
# 4    47   F  53116         108  24.9      Diabetes
# 5    46   F  53118         110  25.0      Migraine

# %%
df.ZIP.nunique()
# Out:
# 5

# %%
df_numerical_qi = df[["Age", "ZIP"]]
print(df_numerical_qi.shape)
df_numerical_qi_dist = pdist(df_numerical_qi)
df_numerical_qi_dist_sq = squareform(df_numerical_qi_dist)
print(df_numerical_qi_dist_sq.shape)
# Out:
# (40, 2)
# (40, 40)

# %%
for i in

# %%
df
# Out:
#     Age Sex    ZIP  SystolicBP   BMI     Diagnosis  Sum_of_Distances
# ID
# 1    27   F  53116         108  27.1  Hypertension          0.000000
# 2    66   M  53118         123  25.2      Migraine         39.051248
# 3    59   M  53118         126  22.8        Asthma         32.062439
# 4    47   F  53116         108  24.9      Diabetes         20.000000
# 5    46   F  53118         110  25.0      Migraine         19.104973
# 6    70   M  53118         124  29.5        Cancer         43.046487
# 7    26   F  53116          90  25.1      Diabetes          1.000000
# 8    61   M  53116         127  26.4      Diabetes         34.000000
# 9    33   M  53117         101  27.2        Cancer          6.082763
# 10   27   M  53115         102  20.1           Flu          1.000000
# 11   52   M  53115         122  23.2  Hypertension         25.019992
# 12   77   F  53115         137  24.3      Diabetes         50.009999
# 13   63   F  53118         130  24.6        Cancer         36.055513
# 14   65   F  53117         124  22.3      Migraine         38.013156
# 15   62   F  53118         119  27.1        Asthma         35.057096
# 16   66   F  53118         125  25.3      Diabetes         39.051248
# 17   51   M  53117         100  21.1        Cancer         24.020824
# 18   29   F  53117          90  20.7  Hypertension          2.236068
# 19   69   M  53115         114  26.8  Hypertension         42.011903
# 20   47   M  53115         104  26.6  Hypertension         20.024984
# 21   50   M  53117         120  29.7        Cancer         23.021729
# 22   43   M  53117         103  31.5      Diabetes         16.031220
# 23   32   F  53117         101  24.5           Flu          5.099020
# 24   74   M  53118         143  23.9  Hypertension         47.042534
# 25   66   F  53117         122  20.5  Hypertension         39.012818
# 26   58   F  53117         128  25.9      Diabetes         31.016125
# 27   44   M  53117         103  22.2        Asthma         17.029386
# 28   68   F  53116         125  24.9  Hypertension         41.000000
# 29   53   F  53115         108  23.4      Diabetes         26.019224
# 30   47   F  53116         111  24.1        Cancer         20.000000
# 31   47   M  53115         123  27.2           Flu         20.024984
# 32   34   F  53116          90  24.0        Asthma          7.000000
# 33   27   F  53119         107  22.7      Diabetes          3.000000
# 34   53   F  53115         120  22.3      Migraine         26.019224
# 35   72   M  53115         123  22.1      Migraine         45.011110
# 36   25   F  53116          90  21.7      Migraine          2.000000
# 37   70   F  53116         129  26.0        Cancer         43.000000
# 38   69   F  53117         122  30.4      Migraine         42.011903
# 39   37   M  53117         111  24.1           Flu         10.049876
# 40   58   M  53118         121  27.7  Hypertension         31.064449

# %%
# Out:
# (780,)
